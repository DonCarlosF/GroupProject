# %% [markdown]
# ### Import data

# %%
import numpy as np
import pandas as pd 

AppleStoreDF = pd.read_csv('../data/AppleStore.csv')
AppleStoreDescDF = pd.read_csv('../data/appleStore_description.csv')
# AndroidStoreDF = pd.read_csv('../data/android_apps.csv')
VenturesDF = pd.read_excel('../data/startup_venture.xlsx')

# %% [markdown]
# ### Sanity check

# %%
AppleStoreDF.dtypes
# Out:
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# game_enab             int64
# dtype: object

# %%
AppleStoreDF.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# ...

# %%
AppleStoreDF.groupby('prime_genre').user_rating.describe().sort_values(by='mean', ascending=False)
# Out:
#                     count      mean       std  min    25%   50%  75%  max
# prime_genre
# Productivity        178.0  4.005618  0.969869  0.0  4.000  4.50  4.5  5.0
# Music               138.0  3.978261  0.881417  0.0  4.000  4.00  4.5  5.0
# Photo & Video       349.0  3.800860  1.278592  0.0  3.500  4.50  4.5  5.0
# Business             57.0  3.745614  1.254004  0.0  3.500  4.00  4.5  5.0
# Health & Fitness    180.0  3.700000  1.535975  0.0  3.500  4.50  4.5  5.0
# Games              3862.0  3.685008  1.468178  0.0  3.500  4.50  4.5  5.0
# Weather              72.0  3.597222  1.266132  0.0  3.500  4.00  4.5  5.0
# Shopping            122.0  3.540984  1.513834  0.0  3.125  4.00  4.5  5.0
# Reference            64.0  3.453125  1.701350  0.0  3.500  4.00  4.5  5.0
# Travel               81.0  3.376543  1.519726  0.0  3.000  4.00  4.5  5.0
# Education           453.0  3.376380  1.543311  0.0  3.000  4.00  4.5  5.0
# ...

# %%
## Maybe we can conclude something about it..

# %%
AppleStoreDF.sort_values(by="rating_count_tot", ascending=False)
# Out:
#                id                                      track_name  size_bytes  \
# 16      284882215                                        Facebook   389879808
# 590     389801252                                       Instagram   113954816
# 1560    529479190                                  Clash of Clans   116476928
# 809     420009108                                      Temple Run    65921024
# 7       284035177                         Pandora - Music & Radio   130242560
# 862     429047995                                       Pinterest    74778624
# 4       282935706                                           Bible    92774400
# 1730    553834731                                Candy Crush Saga   222846976
# 201     324684580                                   Spotify Music   132510720
# 309     343200656                                     Angry Birds   175966208
# 1449    512939461                                  Subway Surfers   156038144
# ...

# %%
AppleStoreDF.rating_count_tot.describe()
# Out:
# count    1.110000e+04
# mean     8.359482e+03
# std      6.129530e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.000000e+01
# 75%      8.192500e+02
# max      2.974676e+06
# Name: rating_count_tot, dtype: float64

# %%
AppleStoreDF = AppleStoreDF[AppleStoreDF.rating_count_tot > 100] # We keep only relevant data with more than 100 votes

# %%
AppleStoreDF.rating_count_tot.describe()
# Out:
# count    4.489000e+03
# mean     2.065632e+04
# std      9.506600e+04
# min      1.010000e+02
# 25%      3.970000e+02
# 50%      1.572000e+03
# 75%      8.271000e+03
# max      2.974676e+06
# Name: rating_count_tot, dtype: float64

# %%
AppleStoreDF.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  4.489000e+03  4.489000e+03  4489.000000      4.489000e+03
# mean   7.856501e+08  2.048140e+08     1.627238      2.065632e+04
# std    2.789102e+08  3.576867e+08     5.024767      9.506600e+04
# min    2.816565e+08  7.671260e+05     0.000000      1.010000e+02
# 25%    5.197814e+08  5.564109e+07     0.000000      3.970000e+02
# 50%    8.833930e+08  1.060055e+08     0.000000      1.572000e+03
# 75%    1.044872e+09  1.859830e+08     1.990000      8.271000e+03
# max    1.187617e+09  4.025970e+09   249.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       4489.000000  4489.000000      4489.000000      4489.000000
# mean         732.733125     4.150813         3.984406        37.326353
# std         4944.352801     0.596689         1.112080         3.834967
# min            0.000000     1.000000         0.000000         9.000000
# ...

# %% [markdown]
# ### Plotting data

# %%
AppleStoreDF.groupby("user_rating").rating_count_tot.describe()
##As we don't have the number of downloads for the app, we will consider the number of rating as a good indicator for the number of downloads
# Out:
#               count          mean            std    min     25%     50%  \
# user_rating
# 1.0             4.0    209.750000     109.338542  117.0  138.75   180.0
# 1.5            21.0    505.047619     512.559994  102.0  185.00   354.0
# 2.0            42.0   7288.000000   29772.478921  102.0  228.00   752.5
# 2.5           102.0  10380.578431   43313.243228  101.0  244.75   602.5
# 3.0           194.0  14748.154639   52852.354840  101.0  212.50   663.0
# 3.5           432.0  25168.090278  154039.257700  105.0  265.25   815.5
# 4.0          1195.0  10648.538075   47122.393319  101.0  299.00   951.0
# 4.5          2221.0  26405.445745  107282.142519  101.0  650.00  2496.0
# 5.0           278.0  22462.676259   63825.200570  108.0  798.00  2883.0
#
#                   75%        max
# user_rating
# 1.0            251.00      362.0
# 1.5            491.00     1999.0
# 2.0           2162.00   187315.0
# 2.5           2180.75   323905.0
# 3.0           2779.00   508808.0
# ...

# %%
p1= pd.DataFrame(data= AppleStoreDF.groupby("user_rating").rating_count_tot.describe())

# %%
p1.plot(y='mean', title='Average number of votes related to the ratings')

# %%
AppleStoreDF.groupby("user_rating").price.describe()
# Out:
#               count      mean       std   min   25%   50%   75%     max
# user_rating
# 1.0             4.0  3.240000  2.061553  0.99  1.74  3.49  4.99    4.99
# 1.5            21.0  1.185714  1.564876  0.00  0.00  0.00  1.99    4.99
# 2.0            42.0  0.450476  1.060347  0.00  0.00  0.00  0.00    3.99
# 2.5           102.0  0.801275  1.708669  0.00  0.00  0.00  0.99    9.99
# 3.0           194.0  0.945619  2.104586  0.00  0.00  0.00  0.99   14.99
# 3.5           432.0  1.547199  4.326705  0.00  0.00  0.00  1.99   74.99
# 4.0          1195.0  1.925205  7.885634  0.00  0.00  0.00  2.99  249.99
# 4.5          2221.0  1.588023  3.479179  0.00  0.00  0.00  1.99   59.99
# 5.0           278.0  1.750719  3.016308  0.00  0.00  0.00  2.99   29.99

# %%
p2= pd.DataFrame(data= AppleStoreDF.groupby("user_rating").price.describe())
p2.plot(y='mean', title='Average price related to the rating')
